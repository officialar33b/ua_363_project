# %%
import numpy as np 
import pandas as pd 
import os

# %%
income_path = r"C:\Users\96653\OneDrive - University of Arizona\Documents\DATA 363\Education vs sunny weather\county\Final Analysis\US Median Household Income by County Cleaned.csv"
print(os.path.exists(income_path))
# Out:
# True

# %%
income_df = pd.read_csv(income_path)
income_df.head(10)
# Out:
#    Unnamed: 0 STATE  CWA  COUNTYNAME   FIPS TIME_ZONE FE_AREA      LON  \
# 0           0    ME  CAR  Washington  23029         E      se -67.6361
# 1           1    GA  CHS    McIntosh  13191         E      se -81.2646
# 2           2    GA  CHS     Liberty  13179         E      se -81.2103
# 3           3    PR  SJU    Adjuntas  72001         V     NaN -66.7542
# 4           4    CT  BOX    Hartford   9003         E      nn -72.7328
# 5           5    CT  BOX     Tolland   9013         E      nn -72.3365
# 6           6    CT  BOX     Windham   9015         E      nn -71.9875
# 7           7    MA  BOX   Nantucket  25019         E      se -70.0744
# 8           8    MD  LWX     Garrett  24023         E      ww -79.2739
# 9           9    VT  BTV     Windsor  50027         E      ss -72.5855
#
#        LAT  Shape_Leng  Shape_Area  FIPS_INT  \
# 0  45.0363   15.828314    0.820504     23029
# 1  31.5329    2.696162    0.007127     13191
# 2  31.7093    0.914666    0.003073     13179
# ...

# %%
income_df.columns
# Out:
# Index(['Unnamed: 0', 'STATE', 'CWA', 'COUNTYNAME', 'FIPS', 'TIME_ZONE',
#        'FE_AREA', 'LON', 'LAT', 'Shape_Leng', 'Shape_Area', 'FIPS_INT',
#        'geometry', 'County', 'Value (Dollars)',
#        'Rank within US (of 3142 counties)', 'County_Name', 'State'],
#       dtype='object')

# %%
clean_df = income_df[['COUNTYNAME', 'FIPS', 'Value (Dollars)']]

# %%
clean_df.to_csv(r"US Median Household Income by County Final.csv")
